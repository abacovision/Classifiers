# %% [markdown]
# # CREATED BY: FILIPY
# ### LINEAR IMAGE CLASSIFICATION FOR CSV DATASETS
# ### LAST EDIT: 12/12/2025

# %%
import pandas as pd
#Downgraded numpy for compatibility purposes
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
import pickle
# Out:
# /home/filipy/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "

# %%
def train(path_train):
    try:
        if type(path_train) != str:
            raise ValueError


        p = Path(path_train)
        rnd = np.random.default_rng()
        bias = rnd.random(3072,)
        bias = np.transpose(bias)
        if p.exists():
            #OPEN THE FILE
            with open(p, 'rb') as train:
                #UNPICKLE THE FILE
                df_temp = pickle.load(train, encoding='bytes')
                #TAKE JUST WHAT WE NEED
                X = df_temp[b'data']
                Y = np.array(df_temp[b'labels'])
                Y = np.transpose(Y)
                #RESHAPE FEATURES
                X = X.reshape(10000,3072)
            #CREATE WEIGHTS VECTOR
            weights = rnd.random((10,3072))
            #TODO:
            #SVM algorithm to train model with one-vs-one approach

            return X, Y
        else:
            raise FileNotFoundError(path_train)
        return weights, X, Y, bias
    except Exception as e:
        raise e

# %%
X, Y = train('dataset/data_batch_1')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 X, Y = train('dataset/data_batch_1')
#
# Cell In[2], line 32, in train(path_train)
#      30     return weights, X, Y, bias
#      31 except Exception as e:
# ---> 32     raise e
#
# Cell In[2], line 29, in train(path_train)
#      27         return X, Y
#      28     else:
# ---> 29         raise FileNotFoundError(path_train)
#      30     return weights, X, Y, bias
#      31 except Exception as e:
#
# FileNotFoundError: dataset/data_batch_1

# %%
print(f'Y lenght: {len(Y)}')
print(f'X shape: {X.shape}')
# Out:
# Y lenght: 10000
# X shape: (10000, 3072)
